# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# 'c:\users\windows' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#Memasang library yang dibutuhkan
import re
import string
import nltk
#nltk.download('all')
from nltk.tokenize import word_tokenize

# %%
#Membaca file
f = open("D:/Document/KULIAH/Semester 5/DSDA/praktikum/news2.txt","r") #Pastikan sesuai dengan directory file
text = f.read()
f.close()

print("Bacaan:\n----------------\n", text)
# Out:
# Bacaan:
# ----------------
#  Harga komoditas dunia mayoritas menguat pada bulan Oktober 2021 didorong oleh pasokan yang menipis di pasar. Beberapa komoditas bahkan mencapai rekor harga tertinggi sepanjang masa seperti timah, sawit, dan aluminium. Akan tetapi laju komoditas juga "dihantui" oleh krisis energi dan perlambatan pertumbuhan ekonomi di China sebagai negara konsumen komoditas terbesar di dunia. al ini memicu kecemasan akan pelemahan permintaan dari China yang bisa menekan harga komoditas. Reuters mengabarkan kondisi tersebut bakal terus berlanjut hingga Maret nanti. Selain itu, harga CPO terus menguat di tengah masifnya program biodisel untuk transportasi di Indonesia maupun Malaysia. Di urutan kedua adalah aluminium yang harganya naik 9,92% sepanjang Oktober 2021. Pasokan menjadi terbatas karena adanya pengetatan penggunaan listrik yang membuat produksi aluminium di China tidak optimal. Batu bara juga masuk ke dalam golongan komoditas yang memiliki kinerja negatif. Harga batu bara sebenarnya sempat mencapai harga tertinggi sepanjang masa pada 5 Oktober. Akan tetapi, reli itu menyusut menyusul aksi ambil untung investor dan langkah pemerintah China yang ingin mengendalikan harga batu bara.

# %%
#Mengubah huruf menjadi huruf kecil
text = text.lower()
print("Huruf kecil semua:\n----------------\n", text)
# Out:
# Huruf kecil semua:
# ----------------
#  harga komoditas dunia mayoritas menguat pada bulan oktober 2021 didorong oleh pasokan yang menipis di pasar. beberapa komoditas bahkan mencapai rekor harga tertinggi sepanjang masa seperti timah, sawit, dan aluminium. akan tetapi laju komoditas juga "dihantui" oleh krisis energi dan perlambatan pertumbuhan ekonomi di china sebagai negara konsumen komoditas terbesar di dunia. al ini memicu kecemasan akan pelemahan permintaan dari china yang bisa menekan harga komoditas. reuters mengabarkan kondisi tersebut bakal terus berlanjut hingga maret nanti. selain itu, harga cpo terus menguat di tengah masifnya program biodisel untuk transportasi di indonesia maupun malaysia. di urutan kedua adalah aluminium yang harganya naik 9,92% sepanjang oktober 2021. pasokan menjadi terbatas karena adanya pengetatan penggunaan listrik yang membuat produksi aluminium di china tidak optimal. batu bara juga masuk ke dalam golongan komoditas yang memiliki kinerja negatif. harga batu bara sebenarnya sempat mencapai harga tertinggi sepanjang masa pada 5 oktober. akan tetapi, reli itu menyusut menyusul aksi ambil untung investor dan langkah pemerintah china yang ingin mengendalikan harga batu bara.

# %%
#Menghapus angka pada paragraf
text = re.sub(r"\d+", "", text)
print("Menghilangkan angka:\n----------------\n", text)
# Out:
# Menghilangkan angka:
# ----------------
#  harga komoditas dunia mayoritas menguat pada bulan oktober  didorong oleh pasokan yang menipis di pasar. beberapa komoditas bahkan mencapai rekor harga tertinggi sepanjang masa seperti timah, sawit, dan aluminium. akan tetapi laju komoditas juga "dihantui" oleh krisis energi dan perlambatan pertumbuhan ekonomi di china sebagai negara konsumen komoditas terbesar di dunia. al ini memicu kecemasan akan pelemahan permintaan dari china yang bisa menekan harga komoditas. reuters mengabarkan kondisi tersebut bakal terus berlanjut hingga maret nanti. selain itu, harga cpo terus menguat di tengah masifnya program biodisel untuk transportasi di indonesia maupun malaysia. di urutan kedua adalah aluminium yang harganya naik ,% sepanjang oktober . pasokan menjadi terbatas karena adanya pengetatan penggunaan listrik yang membuat produksi aluminium di china tidak optimal. batu bara juga masuk ke dalam golongan komoditas yang memiliki kinerja negatif. harga batu bara sebenarnya sempat mencapai harga tertinggi sepanjang masa pada  oktober. akan tetapi, reli itu menyusut menyusul aksi ambil untung investor dan langkah pemerintah china yang ingin mengendalikan harga batu bara.

# %%
#Menghapus tanda baca
text = text.translate(str.maketrans("","",string.punctuation))
print("Menghilangkan Tanda Baca:\n----------------\n",text)
# Out:
# Menghilangkan Tanda Baca:
# ----------------
#  harga komoditas dunia mayoritas menguat pada bulan oktober  didorong oleh pasokan yang menipis di pasar beberapa komoditas bahkan mencapai rekor harga tertinggi sepanjang masa seperti timah sawit dan aluminium akan tetapi laju komoditas juga dihantui oleh krisis energi dan perlambatan pertumbuhan ekonomi di china sebagai negara konsumen komoditas terbesar di dunia al ini memicu kecemasan akan pelemahan permintaan dari china yang bisa menekan harga komoditas reuters mengabarkan kondisi tersebut bakal terus berlanjut hingga maret nanti selain itu harga cpo terus menguat di tengah masifnya program biodisel untuk transportasi di indonesia maupun malaysia di urutan kedua adalah aluminium yang harganya naik  sepanjang oktober  pasokan menjadi terbatas karena adanya pengetatan penggunaan listrik yang membuat produksi aluminium di china tidak optimal batu bara juga masuk ke dalam golongan komoditas yang memiliki kinerja negatif harga batu bara sebenarnya sempat mencapai harga tertinggi sepanjang masa pada  oktober akan tetapi reli itu menyusut menyusul aksi ambil untung investor dan langkah pemerintah china yang ingin mengendalikan harga batu bara

# %%
#6.	Menghapus karakter kosong
text = text.strip()
print("\nKarakter Kosong hilang:\n----------------\n",text)
# Out:
# Karakter Kosong hilang:
# ----------------
#  harga komoditas dunia mayoritas menguat pada bulan oktober  didorong oleh pasokan yang menipis di pasar beberapa komoditas bahkan mencapai rekor harga tertinggi sepanjang masa seperti timah sawit dan aluminium akan tetapi laju komoditas juga dihantui oleh krisis energi dan perlambatan pertumbuhan ekonomi di china sebagai negara konsumen komoditas terbesar di dunia al ini memicu kecemasan akan pelemahan permintaan dari china yang bisa menekan harga komoditas reuters mengabarkan kondisi tersebut bakal terus berlanjut hingga maret nanti selain itu harga cpo terus menguat di tengah masifnya program biodisel untuk transportasi di indonesia maupun malaysia di urutan kedua adalah aluminium yang harganya naik  sepanjang oktober  pasokan menjadi terbatas karena adanya pengetatan penggunaan listrik yang membuat produksi aluminium di china tidak optimal batu bara juga masuk ke dalam golongan komoditas yang memiliki kinerja negatif harga batu bara sebenarnya sempat mencapai harga tertinggi sepanjang masa pada  oktober akan tetapi reli itu menyusut menyusul aksi ambil untung investor dan langkah pemerintah china yang ingin mengendalikan harga batu bara

# %%
#7.	Proses tokenizing
tokens = word_tokenize(text)
print("Tokenizing:\n----------------\n", tokens)
# Out:
# Tokenizing:
# ----------------
#  ['harga', 'komoditas', 'dunia', 'mayoritas', 'menguat', 'pada', 'bulan', 'oktober', 'didorong', 'oleh', 'pasokan', 'yang', 'menipis', 'di', 'pasar', 'beberapa', 'komoditas', 'bahkan', 'mencapai', 'rekor', 'harga', 'tertinggi', 'sepanjang', 'masa', 'seperti', 'timah', 'sawit', 'dan', 'aluminium', 'akan', 'tetapi', 'laju', 'komoditas', 'juga', 'dihantui', 'oleh', 'krisis', 'energi', 'dan', 'perlambatan', 'pertumbuhan', 'ekonomi', 'di', 'china', 'sebagai', 'negara', 'konsumen', 'komoditas', 'terbesar', 'di', 'dunia', 'al', 'ini', 'memicu', 'kecemasan', 'akan', 'pelemahan', 'permintaan', 'dari', 'china', 'yang', 'bisa', 'menekan', 'harga', 'komoditas', 'reuters', 'mengabarkan', 'kondisi', 'tersebut', 'bakal', 'terus', 'berlanjut', 'hingga', 'maret', 'nanti', 'selain', 'itu', 'harga', 'cpo', 'terus', 'menguat', 'di', 'tengah', 'masifnya', 'program', 'biodisel', 'untuk', 'transportasi', 'di', 'indonesia', 'maupun', 'malaysia', 'di', 'urutan', 'kedua', 'adalah', 'aluminium', 'yang', 'harganya', 'naik', 'sepanjang', 'oktober', 'pasokan', 'menjadi', 'terbatas', 'karena', 'adanya', 'pengetatan', 'penggunaan', 'listrik', 'yang', 'membuat', 'produksi', 'aluminium', 'di', 'china', 'tidak', 'optimal', 'batu', 'bara', 'juga', 'masuk', 'ke', 'dalam', 'golongan', 'komoditas', 'yang', 'memiliki', 'kinerja', 'negatif', 'harga', 'batu', 'bara', 'sebenarnya', 'sempat', 'mencapai', 'harga', 'tertinggi', 'sepanjang', 'masa', 'pada', 'oktober', 'akan', 'tetapi', 'reli', 'itu', 'menyusut', 'menyusul', 'aksi', 'ambil', 'untung', 'investor', 'dan', 'langkah', 'pemerintah', 'china', 'yang', 'ingin', 'mengendalikan', 'harga', 'batu', 'bara']

# %%
#8.	Memasang library Sastrawi
#!{sys.executable} -m pip install Sastrawi
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import matplotlib.pyplot as plt

# %%
#Proses filter menggunakan Sastrawi
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
text = stopword.remove(text)
print("\nSetelah filtering:\n----------------\n", text)
# Out:
# Setelah filtering:
# ----------------
#  harga komoditas dunia mayoritas menguat bulan oktober  didorong pasokan menipis pasar beberapa komoditas bahkan mencapai rekor harga tertinggi sepanjang masa timah sawit aluminium tetapi laju komoditas dihantui krisis energi perlambatan pertumbuhan ekonomi china negara konsumen komoditas terbesar dunia al memicu kecemasan pelemahan permintaan china bisa menekan harga komoditas reuters mengabarkan kondisi tersebut bakal terus berlanjut hingga maret selain harga cpo terus menguat tengah masifnya program biodisel transportasi indonesia maupun malaysia urutan kedua aluminium harganya naik  sepanjang oktober  pasokan menjadi terbatas adanya pengetatan penggunaan listrik membuat produksi aluminium china optimal batu bara masuk dalam golongan komoditas memiliki kinerja negatif harga batu bara sebenarnya sempat mencapai harga tertinggi sepanjang masa  oktober tetapi reli menyusut menyusul aksi ambil untung investor langkah pemerintah china ingin mengendalikan harga batu bara

# %%
#10.	Proses Stemming Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()
text = stemmer.stem(text)
print("\nOutput stemming:\n----------------\n", text)
# Out:
# Output stemming:
# ----------------
#  harga komoditas dunia mayoritas kuat bulan oktober dorong pasok tip pasar beberapa komoditas bahkan capai rekor harga tinggi panjang masa timah sawit aluminium tetapi laju komoditas hantu krisis energi lambat tumbuh ekonomi china negara konsumen komoditas besar dunia al picu cemas lemah minta china bisa tekan harga komoditas reuters abar kondisi sebut bakal terus lanjut hingga maret selain harga cpo terus kuat tengah masif program biodisel transportasi indonesia maupun malaysia urut dua aluminium harga naik panjang oktober pasok jadi batas ada ketat guna listrik buat produksi aluminium china optimal batu bara masuk dalam golong komoditas milik kerja negatif harga batu bara benar sempat capai harga tinggi panjang masa oktober tetapi reli susut susul aksi ambil untung investor langkah perintah china ingin kendali harga batu bara

# %%
#11.	Frekuensi huruf yang muncul menggunakan Sastrawi
tf = FreqDist(tokens)
print("\nTerm Frequency:\n----------------\n", tf.most_common())
# Out:
# Term Frequency:
# ----------------
#  [('harga', 7), ('di', 7), ('komoditas', 6), ('yang', 6), ('china', 4), ('oktober', 3), ('sepanjang', 3), ('dan', 3), ('aluminium', 3), ('akan', 3), ('batu', 3), ('bara', 3), ('dunia', 2), ('menguat', 2), ('pada', 2), ('oleh', 2), ('pasokan', 2), ('mencapai', 2), ('tertinggi', 2), ('masa', 2), ('tetapi', 2), ('juga', 2), ('terus', 2), ('itu', 2), ('mayoritas', 1), ('bulan', 1), ('didorong', 1), ('menipis', 1), ('pasar', 1), ('beberapa', 1), ('bahkan', 1), ('rekor', 1), ('seperti', 1), ('timah', 1), ('sawit', 1), ('laju', 1), ('dihantui', 1), ('krisis', 1), ('energi', 1), ('perlambatan', 1), ('pertumbuhan', 1), ('ekonomi', 1), ('sebagai', 1), ('negara', 1), ('konsumen', 1), ('terbesar', 1), ('al', 1), ('ini', 1), ('memicu', 1), ('kecemasan', 1), ('pelemahan', 1), ('permintaan', 1), ('dari', 1), ('bisa', 1), ('menekan', 1), ('reuters', 1), ('mengabarkan', 1), ('kondisi', 1), ('tersebut', 1), ('bakal', 1), ('berlanjut', 1), ('hingga', 1), ('maret', 1), ('nanti', 1), ('selain', 1), ('cpo', 1), ('tengah', 1), ('masifnya', 1), ('program', 1), ('biodisel', 1), ('untuk', 1), ('transportasi', 1), ('indonesia', 1), ('maupun', 1), ('malaysia', 1), ('urutan', 1), ('kedua', 1), ('adalah', 1), ('harganya', 1), ('naik', 1), ('menjadi', 1), ('terbatas', 1), ('karena', 1), ('adanya', 1), ('pengetatan', 1), ('penggunaan', 1), ('listrik', 1), ('membuat', 1), ('produksi', 1), ('tidak', 1), ('optimal', 1), ('masuk', 1), ('ke', 1), ('dalam', 1), ('golongan', 1), ('memiliki', 1), ('kinerja', 1), ('negatif', 1), ('sebenarnya', 1), ('sempat', 1), ('reli', 1), ('menyusut', 1), ('menyusul', 1), ('aksi', 1), ('ambil', 1), ('untung', 1), ('investor', 1), ('langkah', 1), ('pemerintah', 1), ('ingin', 1), ('mengendalikan', 1)]

# %%
#12.	Kata yang sering muncul menggunakan Sastrawi
word, frequency= tf.most_common()[0]
print("\nKeyword yang paling banyak muncul:\n----------------\n", word, "=", frequency , "\n")
# Out:
# Keyword yang paling banyak muncul:
# ----------------
#  harga = 7

# %%
#13.	Keseluruhan kata yang muncul
print("\nKeseluruhan keywords:\n----------------\n")
for word, frequency in tf.most_common():
    print(word, ":", frequency)
# Out:
# Keseluruhan keywords:
# ----------------
#
# harga : 7
# di : 7
# komoditas : 6
# yang : 6
# china : 4
# oktober : 3
# sepanjang : 3
# dan : 3
# aluminium : 3
# akan : 3
# batu : 3
# bara : 3
# dunia : 2
# menguat : 2
# pada : 2
# oleh : 2
# pasokan : 2
# mencapai : 2
# tertinggi : 2
# masa : 2
# tetapi : 2
# juga : 2
# terus : 2
# itu : 2
# mayoritas : 1
# bulan : 1
# didorong : 1
# menipis : 1
# pasar : 1
# beberapa : 1
# bahkan : 1
# rekor : 1
# seperti : 1
# timah : 1
# sawit : 1
# laju : 1
# dihantui : 1
# krisis : 1
# energi : 1
# perlambatan : 1
# pertumbuhan : 1
# ekonomi : 1
# sebagai : 1
# negara : 1
# konsumen : 1
# terbesar : 1
# al : 1
# ini : 1
# memicu : 1
# kecemasan : 1
# pelemahan : 1
# permintaan : 1
# dari : 1
# bisa : 1
# menekan : 1
# reuters : 1
# mengabarkan : 1
# kondisi : 1
# tersebut : 1
# bakal : 1
# berlanjut : 1
# hingga : 1
# maret : 1
# nanti : 1
# selain : 1
# cpo : 1
# tengah : 1
# masifnya : 1
# program : 1
# biodisel : 1
# untuk : 1
# transportasi : 1
# indonesia : 1
# maupun : 1
# malaysia : 1
# urutan : 1
# kedua : 1
# adalah : 1
# harganya : 1
# naik : 1
# menjadi : 1
# terbatas : 1
# karena : 1
# adanya : 1
# pengetatan : 1
# penggunaan : 1
# listrik : 1
# membuat : 1
# produksi : 1
# tidak : 1
# optimal : 1
# masuk : 1
# ke : 1
# dalam : 1
# golongan : 1
# memiliki : 1
# kinerja : 1
# negatif : 1
# sebenarnya : 1
# sempat : 1
# reli : 1
# menyusut : 1
# menyusul : 1
# aksi : 1
# ambil : 1
# untung : 1
# investor : 1
# langkah : 1
# pemerintah : 1
# ingin : 1
# mengendalikan : 1

# %%
#14.	Plot data kata yang sering muncul
tf.plot(cumulative=False)
plt.show()

# %%
#15.	Memasang library Porter
from nltk.stem import PorterStemmer

# %%
#16.	Proses filter menggunakan Porter
listStopword = set(stopwords.words('indonesian'))
tmpstr = []
for t in tokens:
    if t not in listStopword:
        tmpstr.append(t)
        tokens=tmpstr
print("\nSetelah filtering\n----------------\n", tokens)
# Out:
# Setelah filtering
# ----------------
#  ['harga', 'komoditas', 'dunia', 'mayoritas', 'menguat', 'oktober', 'didorong', 'pasokan', 'menipis', 'pasar', 'komoditas', 'mencapai', 'rekor', 'harga', 'tertinggi', 'timah', 'sawit', 'aluminium', 'laju', 'komoditas', 'dihantui', 'krisis', 'energi', 'perlambatan', 'pertumbuhan', 'ekonomi', 'china', 'negara', 'konsumen', 'komoditas', 'terbesar', 'dunia', 'al', 'memicu', 'kecemasan', 'pelemahan', 'permintaan', 'china', 'menekan', 'harga', 'komoditas', 'reuters', 'mengabarkan', 'kondisi', 'berlanjut', 'maret', 'harga', 'cpo', 'menguat', 'masifnya', 'program', 'biodisel', 'transportasi', 'indonesia', 'malaysia', 'urutan', 'aluminium', 'harganya', 'oktober', 'pasokan', 'terbatas', 'pengetatan', 'penggunaan', 'listrik', 'produksi', 'aluminium', 'china', 'optimal', 'batu', 'bara', 'masuk', 'golongan', 'komoditas', 'memiliki', 'kinerja', 'negatif', 'harga', 'batu', 'bara', 'mencapai', 'harga', 'tertinggi', 'oktober', 'reli', 'menyusut', 'menyusul', 'aksi', 'ambil', 'untung', 'investor', 'langkah', 'pemerintah', 'china', 'mengendalikan', 'harga', 'batu', 'bara']

# %%
#17.	Proses Stemming menggunakan Porter
tmpstr = []
ps = PorterStemmer()
for k in tokens:
    tmpstr.append(ps.stem(k))
tokens=tmpstr
print("\nOutput stemming:\n----------------\n", tokens)
# Out:
# Output stemming:
# ----------------
#  ['harga', 'komodita', 'dunia', 'mayorita', 'menguat', 'oktob', 'didorong', 'pasokan', 'menipi', 'pasar', 'komodita', 'mencapai', 'rekor', 'harga', 'tertinggi', 'timah', 'sawit', 'aluminium', 'laju', 'komodita', 'dihantui', 'krisi', 'energi', 'perlambatan', 'pertumbuhan', 'ekonomi', 'china', 'negara', 'konsumen', 'komodita', 'terbesar', 'dunia', 'al', 'memicu', 'kecemasan', 'pelemahan', 'permintaan', 'china', 'menekan', 'harga', 'komodita', 'reuter', 'mengabarkan', 'kondisi', 'berlanjut', 'maret', 'harga', 'cpo', 'menguat', 'masifnya', 'program', 'biodisel', 'transportasi', 'indonesia', 'malaysia', 'urutan', 'aluminium', 'harganya', 'oktob', 'pasokan', 'terbata', 'pengetatan', 'penggunaan', 'listrik', 'produksi', 'aluminium', 'china', 'optim', 'batu', 'bara', 'masuk', 'golongan', 'komodita', 'memiliki', 'kinerja', 'negatif', 'harga', 'batu', 'bara', 'mencapai', 'harga', 'tertinggi', 'oktob', 'reli', 'menyusut', 'menyusul', 'aksi', 'ambil', 'untung', 'investor', 'langkah', 'pemerintah', 'china', 'mengendalikan', 'harga', 'batu', 'bara']

# %%
#18.	Frekuensi kata yang muncul menggunakan Porter
tf = FreqDist(tokens)
print("\nTerm Frequency:\n----------------\n", tf.most_common())
# Out:
# Term Frequency:
# ----------------
#  [('harga', 7), ('komodita', 6), ('china', 4), ('oktob', 3), ('aluminium', 3), ('batu', 3), ('bara', 3), ('dunia', 2), ('menguat', 2), ('pasokan', 2), ('mencapai', 2), ('tertinggi', 2), ('mayorita', 1), ('didorong', 1), ('menipi', 1), ('pasar', 1), ('rekor', 1), ('timah', 1), ('sawit', 1), ('laju', 1), ('dihantui', 1), ('krisi', 1), ('energi', 1), ('perlambatan', 1), ('pertumbuhan', 1), ('ekonomi', 1), ('negara', 1), ('konsumen', 1), ('terbesar', 1), ('al', 1), ('memicu', 1), ('kecemasan', 1), ('pelemahan', 1), ('permintaan', 1), ('menekan', 1), ('reuter', 1), ('mengabarkan', 1), ('kondisi', 1), ('berlanjut', 1), ('maret', 1), ('cpo', 1), ('masifnya', 1), ('program', 1), ('biodisel', 1), ('transportasi', 1), ('indonesia', 1), ('malaysia', 1), ('urutan', 1), ('harganya', 1), ('terbata', 1), ('pengetatan', 1), ('penggunaan', 1), ('listrik', 1), ('produksi', 1), ('optim', 1), ('masuk', 1), ('golongan', 1), ('memiliki', 1), ('kinerja', 1), ('negatif', 1), ('reli', 1), ('menyusut', 1), ('menyusul', 1), ('aksi', 1), ('ambil', 1), ('untung', 1), ('investor', 1), ('langkah', 1), ('pemerintah', 1), ('mengendalikan', 1)]

# %%
#19.	Kata yang sering muncul menggunakan Porter
word, frequency=tf.most_common()[0]
print("\nKeyword yang paling banyak muncul:\n----------------\n", word, "=", frequency , "\n")
# Out:
# Keyword yang paling banyak muncul:
# ----------------
#  harga = 7

# %%
#20.	Keseluruhan kata yang muncul
print("\nKeseluruhan keywords:\n----------------\n")
for word, frequency in tf.most_common():
    print(word, ":", frequency)
# Out:
# Keseluruhan keywords:
# ----------------
#
# harga : 7
# komodita : 6
# china : 4
# oktob : 3
# aluminium : 3
# batu : 3
# bara : 3
# dunia : 2
# menguat : 2
# pasokan : 2
# mencapai : 2
# tertinggi : 2
# mayorita : 1
# didorong : 1
# menipi : 1
# pasar : 1
# rekor : 1
# timah : 1
# sawit : 1
# laju : 1
# dihantui : 1
# krisi : 1
# energi : 1
# perlambatan : 1
# pertumbuhan : 1
# ekonomi : 1
# negara : 1
# konsumen : 1
# terbesar : 1
# al : 1
# memicu : 1
# kecemasan : 1
# pelemahan : 1
# permintaan : 1
# menekan : 1
# reuter : 1
# mengabarkan : 1
# kondisi : 1
# berlanjut : 1
# maret : 1
# cpo : 1
# masifnya : 1
# program : 1
# biodisel : 1
# transportasi : 1
# indonesia : 1
# malaysia : 1
# urutan : 1
# harganya : 1
# terbata : 1
# pengetatan : 1
# penggunaan : 1
# listrik : 1
# produksi : 1
# optim : 1
# masuk : 1
# golongan : 1
# memiliki : 1
# kinerja : 1
# negatif : 1
# reli : 1
# menyusut : 1
# menyusul : 1
# aksi : 1
# ambil : 1
# untung : 1
# investor : 1
# langkah : 1
# pemerintah : 1
# mengendalikan : 1

# %%
#21.	Plot data yang sering muncul

tf.plot(cumulative=False)
plt.show()
